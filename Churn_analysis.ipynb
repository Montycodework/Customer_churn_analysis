# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Customer-Churn.csv')
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df['TotalCharges'] = df['TotalCharges'].replace(" ","0")
df['TotalCharges']= df['TotalCharges'].astype("float")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
# First sum() for individual columns and second sum() for overall sum of all columns.
df.isnull().sum().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges  TotalCharges
# count    7043.000000  7043.000000     7043.000000   7043.000000
# mean        0.162147    32.371149       64.761692   2279.734304
# std         0.368612    24.559481       30.090047   2266.794470
# min         0.000000     0.000000       18.250000      0.000000
# 25%         0.000000     9.000000       35.500000    398.550000
# 50%         0.000000    29.000000       70.350000   1394.550000
# 75%         0.000000    55.000000       89.850000   3786.600000
# max         1.000000    72.000000      118.750000   8684.800000

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df['customerID'].duplicated().sum() # Individually targeting a unique dataset
# Out:
# 0

# %%
def conv(value):
    if value == 1:
        return 'yes'
    else:
        return 'no'

df['SeniorCitizen'] = df['SeniorCitizen'].apply(conv)

# %% [raw]
# # converted 0 and 1 values of SeniorCitizen to yes/no to make it easier to understand

# %%
# df.head(30)

# %%
# ax = sns.countplot(x = df['Churn'], data = df)
ax = sns.countplot(x = 'Churn', data = df)         # Same work

ax.bar_label(ax.containers[0]) # this line shows the values over bars.
plt.title('Count of Customers Churn')
plt.show()

# %%
# plt.pie(df['Churn'])
# plt.show()
# When i was running these commands ValueError: could not convert string to float: 'No'

# So we need to do the data groupby below
gb = df.groupby('Churn').agg({"Churn":"count"})
gb
# Out:
#        Churn
# Churn
# No      5174
# Yes     1869

# %%
# plt.pie(df['Churn'])
# plt.show()

# updated version---------
plt.pie(gb['Churn'], labels = gb.index, autopct = "%1.2f%%")
plt.title("Percentage of Churned customers", fontsize = 10)
plt.show()

# %% [raw]
# # from given pie chart we can conclude that 26.54% of our customers have chunrned out.
# # Now lets explore the reason behind it.

# %%
# sns.countplot(df['gender'], data = df)
# TypeError: countplot() got multiple values for argument 'data'

# sns.countplot(x = 'gender', data = df)
# ax.bar_label(ax.containers[0])

plt.figure(figsize = (3,3))
sns.countplot(x = 'gender', data = df, hue = 'Churn') # hue make the data more detailed
plt.title("Churned by gender")
plt.show()

# %%
# plt.figure(figsize = (3,3))
# sns.countplot(x = "SeniorCitizen", data = df, hue = 'Churn')
# plt.title("Churned by SeniorCitizen")
# plt.show()

# %%
plt.figure(figsize = (2,4.5))
ax = sns.countplot(x = "SeniorCitizen", data = df)
ax.bar_label(ax.containers[0])
plt.title("Count of customer by Senior citizen")
plt.show()

# %%
total_counts = df.groupby('SeniorCitizen')['Churn'].value_counts(normalize=True).unstack() * 100
fig, ax = plt.subplots(figsize = (4,4))

total_counts.plot(kind='bar', stacked=True, ax=ax, color=['#1f77b4', '#ff7f0e'])

for p in ax.patches:
    width, height = p.get_width(), p.get_height()
    x,y = p.get_xy()
    ax.text(x + width / 2, y + height / 2, f'{height:.1f}%', ha='center',va='center')

plt.title('Churn by senior citizen (stacked bar chart)')
plt.xlabel('SeniorCitizen')
plt.ylabel('Percentage (%)')
plt.xticks(rotation=0)
# plt.legend(title='Churn', loc='upper right')
plt.legend(title='Churn', bbox_to_anchor = (0.9, 0.9))

plt.show()

# %% [raw]
# # Comapartive a greated percentage ofpeople in senior citizen category have chunred

# %%
plt.figure(figsize = (9,4))
sns.histplot(x='tenure', data=df, bins=72, hue='Churn') # Bins help you to spread your data to look into precisely.
plt.show()

# %% [raw]
# #people who have used our services for long time stayed and people who have used our services for short time have churned.

# %%
plt.figure(figsize = (4,4))
ax = sns.countplot(x = "Contract", data = df, hue='Churn')
ax.bar_label(ax.containers[0])
plt.title("Count of customer by Contract")
plt.show()

# %% [raw]
# # peole who have month to month are likely to churn then from who have one or two years of contarct

# %%
df.columns.values
# Out:
# array(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
#        'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract',
#        'PaperlessBilling', 'PaymentMethod', 'MonthlyCharges',
#        'TotalCharges', 'Churn'], dtype=object)

# %%
# Initialize the plot
fig, axes = plt.subplots(3, 3, figsize=(15, 15))  # Adjust rows/columns as needed
axes = axes.flatten()  # Flatten the 2D array for easier indexing

# List of columns to plot
columns = [
    'PhoneService', 'MultipleLines', 'InternetService',
    'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
    'TechSupport', 'StreamingTV', 'StreamingMovies'
]

# Create a countplot for each column
for i, column in enumerate(columns):
    sns.countplot(data=df, x=column, hue=df['Churn'], ax=axes[i], palette="viridis", legend=True)
    axes[i].set_title(f'Countplot for {column}')
    axes[i].set_xlabel(column)
    axes[i].set_ylabel('Count')

# Adjust layout
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize = (5,4))
ax = sns.countplot(x = "PaymentMethod", data = df, hue='Churn')
ax.bar_label(ax.containers[0])
ax.bar_label(ax.containers[1])
plt.title("Churned customers by Payment Method")
plt.xticks(rotation=45)
plt.legend(title='Churn', bbox_to_anchor = (0.9, 0.9))
plt.show()

# %% [raw]
# # Customer is ikely to churn when he/she is using electronic check as a payment method
